# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


df= pd.read_excel('Antigüedad de saldos 17.03.2023.xlsx')
df
# Out:
#     No. CLIENTE                                             NOMBRE  FACTURA  \
# 0          6401                               DONGA HWASUNG MEXICO   F40238
# 1          6401                               DONGA HWASUNG MEXICO   F40353
# 2          4598       PROVEEDORA DE SEGURIDAD INDUSTRIAL DEL GOLFO   F40352
# 3          3930                               INDUSTRIAS LANCERMEX   F40217
# 4          4712                                             HELVEX   F40173
# ..          ...                                                ...      ...
# 159         856  CENTRO DE INVESTIGACION Y DE ESTUDIOS AVANZADO...   F40055
# 160        5926                                 PÚBLICO EN GENERAL  NV00777
# 161        5926                                 PÚBLICO EN GENERAL  NV00778
# 162        5926                                 PÚBLICO EN GENERAL  NV00779
# 163        8429                                  FISHERS QUERETARO   F38248
#
#     FECHA_FACTURA FECHA_VENCIMIENTO  MONTO ADEUDADO
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164 entries, 0 to 163
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   No. CLIENTE        162 non-null    object
#  1   NOMBRE             163 non-null    object
#  2   FACTURA            163 non-null    object
#  3   FECHA_FACTURA      163 non-null    datetime64[ns]
#  4   FECHA_VENCIMIENTO  164 non-null    datetime64[ns]
#  5   MONTO ADEUDADO     163 non-null    float64
# dtypes: datetime64[ns](2), float64(1), object(3)
# memory usage: 7.8+ KB

# %%
filtro1=df[(df["NOMBRE"] == "INDUSTRIAS LANCERMEX")]
filtro1
# Out:
#    No. CLIENTE                NOMBRE FACTURA FECHA_FACTURA FECHA_VENCIMIENTO  \
# 3         3930  INDUSTRIAS LANCERMEX  F40217    2023-02-23        2023-03-25
# 12        3930  INDUSTRIAS LANCERMEX  F40114    2023-02-09        2023-03-11
#
#     MONTO ADEUDADO
# 3         52715.74
# 12        35143.82

# %%
#filtro por filas
filtro2= df.iloc[3:10,: ]          #filas consecutivas
#filtro2= df.iloc[ [2,5], : ]        #filas no consecutivas
filtro2
# Out:
#   No. CLIENTE                          NOMBRE FACTURA FECHA_FACTURA  \
# 3        3930            INDUSTRIAS LANCERMEX  F40217    2023-02-23
# 4        4712                          HELVEX  F40173    2023-02-17
# 5        1429  AUTOLIV STEERING WHEELS MEXICO  F39979    2023-01-24
# 6        1429  AUTOLIV STEERING WHEELS MEXICO  F40319    2023-03-08
# 7        5039                        BUSSMANN  F40082    2023-02-04
# 8         644           CLAVOS NACIONALES C.N  F40340    2023-03-13
# 9         644           CLAVOS NACIONALES C.N  F40351    2023-03-14
#
#   FECHA_VENCIMIENTO  MONTO ADEUDADO
# 3        2023-03-25        52715.74
# 4        2023-04-03        50639.80
# 5        2023-03-25        49416.00
# 6        2023-05-07        49416.00
# 7        2023-02-04        48882.12
# 8        2023-05-12        45216.34
# 9        2023-05-13        45216.34

# %%
filtro3= df.iloc[ : , [1,4,5]]        #columnas no consecutivas
filtro3
# Out:
#                                                 NOMBRE FECHA_VENCIMIENTO  \
# 0                                 DONGA HWASUNG MEXICO        2023-03-26
# 1                                 DONGA HWASUNG MEXICO        2023-04-13
# 2         PROVEEDORA DE SEGURIDAD INDUSTRIAL DEL GOLFO        2023-04-13
# 3                                 INDUSTRIAS LANCERMEX        2023-03-25
# 4                                               HELVEX        2023-04-03
# ..                                                 ...               ...
# 159  CENTRO DE INVESTIGACION Y DE ESTUDIOS AVANZADO...        2023-01-31
# 160                                 PÚBLICO EN GENERAL        2023-03-07
# 161                                 PÚBLICO EN GENERAL        2023-03-09
# 162                                 PÚBLICO EN GENERAL        2023-03-09
# 163                                  FISHERS QUERETARO        2022-05-27
#
#      MONTO ADEUDADO
# 0          97485.94
# 1          97485.94
# 2          64916.21
# ...

# %%
df1= pd.read_excel('Antigüedad de saldos 17.03.2023.xlsx', index_col=1)
df1
# Out:
#                                                    No. CLIENTE  FACTURA  \
# NOMBRE
# DONGA HWASUNG MEXICO                                      6401   F40238
# DONGA HWASUNG MEXICO                                      6401   F40353
# PROVEEDORA DE SEGURIDAD INDUSTRIAL DEL GOLFO              4598   F40352
# INDUSTRIAS LANCERMEX                                      3930   F40217
# HELVEX                                                    4712   F40173
# ...                                                        ...      ...
# CENTRO DE INVESTIGACION Y DE ESTUDIOS AVANZADOS...         856   F40055
# PÚBLICO EN GENERAL                                        5926  NV00777
# PÚBLICO EN GENERAL                                        5926  NV00778
# PÚBLICO EN GENERAL                                        5926  NV00779
# FISHERS QUERETARO                                         8429   F38248
#
#                                                    FECHA_FACTURA  \
# NOMBRE
# ...

# %%
filtro4=df1.loc[["HELVEX","DONGA HWASUNG MEXICO"], ["MONTO ADEUDADO"]]
filtro4
# Out:
#                       MONTO ADEUDADO
# NOMBRE
# HELVEX                      50639.80
# DONGA HWASUNG MEXICO        97485.94
# DONGA HWASUNG MEXICO        97485.94
# DONGA HWASUNG MEXICO        10759.00
# DONGA HWASUNG MEXICO         9396.00

# %%
filtro5=df.head()
filtro5
# Out:
#   No. CLIENTE                                        NOMBRE FACTURA  \
# 0        6401                          DONGA HWASUNG MEXICO  F40238
# 1        6401                          DONGA HWASUNG MEXICO  F40353
# 2        4598  PROVEEDORA DE SEGURIDAD INDUSTRIAL DEL GOLFO  F40352
# 3        3930                          INDUSTRIAS LANCERMEX  F40217
# 4        4712                                        HELVEX  F40173
#
#   FECHA_FACTURA FECHA_VENCIMIENTO  MONTO ADEUDADO
# 0    2023-02-24        2023-03-26        97485.94
# 1    2023-03-14        2023-04-13        97485.94
# 2    2023-03-14        2023-04-13        64916.21
# 3    2023-02-23        2023-03-25        52715.74
# 4    2023-02-17        2023-04-03        50639.80

# %%
filtro6=df.tail()
filtro6
# Out:
#     No. CLIENTE                                             NOMBRE  FACTURA  \
# 159         856  CENTRO DE INVESTIGACION Y DE ESTUDIOS AVANZADO...   F40055
# 160        5926                                 PÚBLICO EN GENERAL  NV00777
# 161        5926                                 PÚBLICO EN GENERAL  NV00778
# 162        5926                                 PÚBLICO EN GENERAL  NV00779
# 163        8429                                  FISHERS QUERETARO   F38248
#
#     FECHA_FACTURA FECHA_VENCIMIENTO  MONTO ADEUDADO
# 159    2023-01-31        2023-01-31           56.00
# 160    2023-03-07        2023-03-07           45.00
# 161    2023-03-09        2023-03-09           40.00
# 162    2023-03-09        2023-03-09           24.01
# 163    2022-05-27        2022-05-27           19.94

# %%
filtro7=df[df["MONTO ADEUDADO"] < 70000]
filtro7
# Out:
#     No. CLIENTE                                             NOMBRE  FACTURA  \
# 2          4598       PROVEEDORA DE SEGURIDAD INDUSTRIAL DEL GOLFO   F40352
# 3          3930                               INDUSTRIAS LANCERMEX   F40217
# 4          4712                                             HELVEX   F40173
# 5          1429                     AUTOLIV STEERING WHEELS MEXICO   F39979
# 6          1429                     AUTOLIV STEERING WHEELS MEXICO   F40319
# ..          ...                                                ...      ...
# 159         856  CENTRO DE INVESTIGACION Y DE ESTUDIOS AVANZADO...   F40055
# 160        5926                                 PÚBLICO EN GENERAL  NV00777
# 161        5926                                 PÚBLICO EN GENERAL  NV00778
# 162        5926                                 PÚBLICO EN GENERAL  NV00779
# 163        8429                                  FISHERS QUERETARO   F38248
#
#     FECHA_FACTURA FECHA_VENCIMIENTO  MONTO ADEUDADO
# ...

# %%
filtro8= df[(df["MONTO ADEUDADO"] < 6000) & (df["FECHA_VENCIMIENTO"] == "2023-03-14")]
filtro8
# Out:
#     No. CLIENTE                                             NOMBRE FACTURA  \
# 85          409  CONSTRUCCIONES ELECTROMECANICAS Y SERVICIOS IN...  F40359
# 101        5926                                 PÚBLICO EN GENERAL  F40362
# 113        2216                                         FRESCOPACK  F40355
# 135        8872                            GABRIELA GARCIA SANCHEZ  F40360
# 139        8228                                      UCH COMERCIAL  F40365
#
#     FECHA_FACTURA FECHA_VENCIMIENTO  MONTO ADEUDADO
# 85     2023-03-14        2023-03-14         4292.00
# 101    2023-03-14        2023-03-14         2694.95
# 113    2023-03-14        2023-03-14         1682.00
# 135    2023-03-14        2023-03-14          754.00
# 139    2023-03-14        2023-03-14          702.96

# %%
filtro9= df[(df["MONTO ADEUDADO"] < 6000) | (df["FECHA_FACTURA"] == "2023-03-14")]
filtro9
# Out:
#     No. CLIENTE                                             NOMBRE  FACTURA  \
# 1          6401                               DONGA HWASUNG MEXICO   F40353
# 2          4598       PROVEEDORA DE SEGURIDAD INDUSTRIAL DEL GOLFO   F40352
# 9           644                              CLAVOS NACIONALES C.N   F40351
# 10         3937                                           RICHALUM   F40361
# 36          417                                            COVEMEX   F40354
# ..          ...                                                ...      ...
# 159         856  CENTRO DE INVESTIGACION Y DE ESTUDIOS AVANZADO...   F40055
# 160        5926                                 PÚBLICO EN GENERAL  NV00777
# 161        5926                                 PÚBLICO EN GENERAL  NV00778
# 162        5926                                 PÚBLICO EN GENERAL  NV00779
# 163        8429                                  FISHERS QUERETARO   F38248
#
#     FECHA_FACTURA FECHA_VENCIMIENTO  MONTO ADEUDADO
# ...

# %%
filtro10=df[~(df["FECHA_FACTURA"] == "2023-03-14")]
filtro10
# Out:
#     No. CLIENTE                                             NOMBRE  FACTURA  \
# 0          6401                               DONGA HWASUNG MEXICO   F40238
# 3          3930                               INDUSTRIAS LANCERMEX   F40217
# 4          4712                                             HELVEX   F40173
# 5          1429                     AUTOLIV STEERING WHEELS MEXICO   F39979
# 6          1429                     AUTOLIV STEERING WHEELS MEXICO   F40319
# ..          ...                                                ...      ...
# 159         856  CENTRO DE INVESTIGACION Y DE ESTUDIOS AVANZADO...   F40055
# 160        5926                                 PÚBLICO EN GENERAL  NV00777
# 161        5926                                 PÚBLICO EN GENERAL  NV00778
# 162        5926                                 PÚBLICO EN GENERAL  NV00779
# 163        8429                                  FISHERS QUERETARO   F38248
#
#     FECHA_FACTURA FECHA_VENCIMIENTO  MONTO ADEUDADO
# ...

# %%
filtro10.to_csv("Enrtegable1.csv")

# %%
df= pd.read_excel('Detalle precios y productos fabricados 2022.xlsx')
df
#lee el archivo
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3     F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                     NOMBRE_CLIENTE  CANT       CVE_ART  \
# 0               PÚBLICO EN GENERAL     1      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE     1      TUA00028
# 2        ANA BARBARA CRUZ PALACIOS     7        TP0007
# 3             OMAR RODRIGUEZ GOMEZ     1        TP0001
# 4               PÚBLICO EN GENERAL     2       BP00242
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1426 entries, 0 to 1425
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CVE_DOC                    1426 non-null   object
#  1   FECHA_DOC                  1426 non-null   datetime64[ns]
#  2   NOMBRE_VENDEDOR            1424 non-null   object
#  3   NOMBRE_CLIENTE             1426 non-null   object
#  4   CANT                       1426 non-null   int64
#  5   CVE_ART                    1426 non-null   object
#  6   DESCR                      1426 non-null   object
#  7   PRECIO_UNITARIO            1426 non-null   float64
#  8   COSTO_UNITARIO             1426 non-null   float64
#  9   COSTO_UNITARIO_CALCULADO   1426 non-null   float64
#  10  SUBTOTAL_PARTIDA           1426 non-null   float64
#  11  COSTO_TOTAL_CALCULADO      1426 non-null   float64
#  12  MARGEN_UNITARIO_CALCULADO  1426 non-null   float64
# ...

# %%
filtro1a=df[(df["NOMBRE_VENDEDOR"] == "ALFREDO CANELA")]
filtro1a
#busca que el nombre del vendedor sea ALFREDO CANELA
# Out:
#      CVE_DOC  FECHA_DOC NOMBRE_VENDEDOR             NOMBRE_CLIENTE  CANT  \
# 18    F37061 2022-01-05  ALFREDO CANELA                   ELICAMEX     5
# 19    F37061 2022-01-05  ALFREDO CANELA                   ELICAMEX     7
# 20    F37061 2022-01-05  ALFREDO CANELA                   ELICAMEX     3
# 29    F37078 2022-01-07  ALFREDO CANELA      CLAVOS NACIONALES C.N    30
# 30    F37083 2022-01-10  ALFREDO CANELA  PEDRO ANTONIO SOTO IBARRA     6
# ...      ...        ...             ...                        ...   ...
# 1405  F39812 2022-12-22  ALFREDO CANELA          CEREALES Y PASTAS    10
# 1407  F39815 2022-12-22  ALFREDO CANELA              START SERVICE     1
# 1408  F39815 2022-12-22  ALFREDO CANELA              START SERVICE     1
# 1409  F39816 2022-12-22  ALFREDO CANELA             TOSTADAS FANNY     6
# 1412  F39824 2022-12-23  ALFREDO CANELA                  MEGO AFEK     1
#
#         CVE_ART                                     DESCR  PRECIO_UNITARIO  \
# ...

# %%
filtro2a= df.iloc[3:10,: ]
filtro2a
#muestra la columna 3 y 10, sin alguna otra restriccion
# Out:
#   CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 3  F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4  F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 5  F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 6  F37044 2022-01-05   DIEGO ARMANDO LEON DURAN
# 7  F37046 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 8  F37048 2022-01-05   DIEGO ARMANDO LEON DURAN
# 9  F37049 2022-01-05   DIEGO ARMANDO LEON DURAN
#
#                         NOMBRE_CLIENTE  CANT   CVE_ART  \
# 3                 OMAR RODRIGUEZ GOMEZ     1    TP0001
# 4                   PÚBLICO EN GENERAL     2   BP00242
# 5                   PÚBLICO EN GENERAL     2   BP00243
# 6  AIRBUS HELICOPTERS MEXICO QUERETARO     1   RP00165
# 7            ANA BARBARA CRUZ PALACIOS     3    TP0001
# 8                   FIDEICOMISO F/1596     1  TUE00207
# 9                   FIDEICOMISO F/1596     1  TUE00207
#
#                                       DESCR  PRECIO_UNITARIO  COSTO_UNITARIO  \
# ...

# %%
filtro3a= df.iloc[ : , [2,4,7]]        #columnas no consecutivas
filtro3a
# Out:
#                 NOMBRE_VENDEDOR  CANT  PRECIO_UNITARIO
# 0     LETICIA RAMIREZ HERNANDEZ     1           434.48
# 1     LETICIA RAMIREZ HERNANDEZ     1          1264.05
# 2      DIEGO ARMANDO LEON DURAN     7           551.61
# 3      DIEGO ARMANDO LEON DURAN     1           140.00
# 4     LETICIA RAMIREZ HERNANDEZ     2           172.41
# ...                         ...   ...              ...
# 1421  LETICIA RAMIREZ HERNANDEZ     6           712.00
# 1422  LETICIA RAMIREZ HERNANDEZ     6           718.60
# 1423  LETICIA RAMIREZ HERNANDEZ     3          2182.35
# 1424  LETICIA RAMIREZ HERNANDEZ     1          5909.84
# 1425         AARON NUÑO CORDOVA    10          1406.00
#
# [1426 rows x 3 columns]

# %%
df1= pd.read_excel('Detalle precios y productos fabricados 2022.xlsx', index_col=2)
df1
# Out:
#                           CVE_DOC  FECHA_DOC                NOMBRE_CLIENTE  \
# NOMBRE_VENDEDOR
# LETICIA RAMIREZ HERNANDEZ  F37034 2022-01-05            PÚBLICO EN GENERAL
# LETICIA RAMIREZ HERNANDEZ  F37036 2022-01-05  JUAN ANTONIO RESENDIZ UGALDE
# DIEGO ARMANDO LEON DURAN   F37041 2022-01-05     ANA BARBARA CRUZ PALACIOS
# DIEGO ARMANDO LEON DURAN   F37042 2022-01-05          OMAR RODRIGUEZ GOMEZ
# LETICIA RAMIREZ HERNANDEZ  F37043 2022-01-05            PÚBLICO EN GENERAL
# ...                           ...        ...                           ...
# LETICIA RAMIREZ HERNANDEZ  F39834 2022-12-23     LUIS ENRIQUE PATIÑO PEREZ
# LETICIA RAMIREZ HERNANDEZ  F39834 2022-12-23     LUIS ENRIQUE PATIÑO PEREZ
# LETICIA RAMIREZ HERNANDEZ  F39835 2022-12-23          SEVEN DAYS ALL SPORT
# LETICIA RAMIREZ HERNANDEZ  F39837 2022-12-23           REVUELTA MONTECARLO
# AARON NUÑO CORDOVA         F39838 2022-12-23                CPEG SOLUTIONS
#
#                            CANT       CVE_ART  \
# ...

# %%
filtro4a=df1.loc[["DIEGO ARMANDO LEON DURAN"], ["PRECIO_UNITARIO"]]
filtro4a
#muestra las columnas donde aparecen los datos DIEGO ARMANDO DURAN Y PRECIO,COMPARANDO FILAS Y CLUMNAS
# Out:
#                           PRECIO_UNITARIO
# NOMBRE_VENDEDOR
# DIEGO ARMANDO LEON DURAN           551.61
# DIEGO ARMANDO LEON DURAN           140.00
# DIEGO ARMANDO LEON DURAN         14000.00
# DIEGO ARMANDO LEON DURAN          1615.00
# DIEGO ARMANDO LEON DURAN          1615.00
# ...                                   ...
# DIEGO ARMANDO LEON DURAN          6300.00
# DIEGO ARMANDO LEON DURAN          2750.00
# DIEGO ARMANDO LEON DURAN           375.00
# DIEGO ARMANDO LEON DURAN         14000.00
# DIEGO ARMANDO LEON DURAN         14000.00
#
# [120 rows x 1 columns]

# %%
filtro5a=df.head(6)
filtro5a
#MUESTRA LAS 5 PRIMERAS FILAS DEL ARCHIVO
# Out:
#   CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR                NOMBRE_CLIENTE  \
# 0  F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
# 1  F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ  JUAN ANTONIO RESENDIZ UGALDE
# 2  F37041 2022-01-05   DIEGO ARMANDO LEON DURAN     ANA BARBARA CRUZ PALACIOS
# 3  F37042 2022-01-05   DIEGO ARMANDO LEON DURAN          OMAR RODRIGUEZ GOMEZ
# 4  F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
# 5  F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
#
#    CANT   CVE_ART                                    DESCR  PRECIO_UNITARIO  \
# 0     1  TUE00244  TUB COBRE 5/16"ØX165MM CIRCULA1.5KW127V           434.48
# 1     1  TUA00028  TUA U" 5/16 ØX250MM 1200W 120V TAP1"NPT          1264.05
# 2     7    TP0007     TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 7 MT           551.61
# 3     1    TP0001     TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 1 MT           140.00
# ...

# %%
filtro6a=df.tail(6)
filtro6a
#MUESTRA LAS ULTIMAS 5 FILAS DEL ARCHIVO
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR             NOMBRE_CLIENTE  \
# 1420  F39833 2022-12-23         AARON NUÑO CORDOVA            TRILOGIQ-MEXICO
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ  LUIS ENRIQUE PATIÑO PEREZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ  LUIS ENRIQUE PATIÑO PEREZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ       SEVEN DAYS ALL SPORT
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ        REVUELTA MONTECARLO
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA             CPEG SOLUTIONS
#
#       CANT       CVE_ART                                     DESCR  \
# 1420     2       PT00079    PT-100 7.5MMØX95MM EXT.48CM 3H C/MACHO
# 1421     6  CS12F1040A00      CAS INOX 1/2"ØX3" 400W 127V EXT.30CM
# 1422     6  CS12H1050A00       CAS INOX 1/2"ØX4" 500W 127V EXT30CM
# 1423     3      TUE00394  TUB INOX 5/16"ØX300MM 5300W 220V "M" ESP
# 1424     1      TUA00470  TUB INOX 1/2"ØX500MM 10KW 220V 2 1/2"NPT
# ...

# %%
filtro7a=df[df["PRECIO_UNITARIO"] < 123]
filtro7a
#BUSCA LAS FILAS DONDE EL PRECIO UNITARIO SEA MAYOR A 123
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 7     F37046 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 89    F37193 2022-01-26  LETICIA RAMIREZ HERNANDEZ
# 93    F37214 2022-01-27  LETICIA RAMIREZ HERNANDEZ
# 192   F37422 2022-02-18  LETICIA RAMIREZ HERNANDEZ
# 307   F37612 2022-03-11  LETICIA RAMIREZ HERNANDEZ
# 344   F37692 2022-03-22  LETICIA RAMIREZ HERNANDEZ
# 346   F37695 2022-03-22  LETICIA RAMIREZ HERNANDEZ
# 372   F37731 2022-03-25  LETICIA RAMIREZ HERNANDEZ
# 422   F37824 2022-04-04  LETICIA RAMIREZ HERNANDEZ
# 489   F37951 2022-04-21  LETICIA RAMIREZ HERNANDEZ
# 549   F38083 2022-05-04  LETICIA RAMIREZ HERNANDEZ
# 676   F38364 2022-06-13             ALFREDO CANELA
# 926   F38836 2022-08-17  LETICIA RAMIREZ HERNANDEZ
# 1096  F39181 2022-09-29  LETICIA RAMIREZ HERNANDEZ
# 1240  F39470 2022-11-01  LETICIA RAMIREZ HERNANDEZ
# 1274  F39550 2022-11-11  LETICIA RAMIREZ HERNANDEZ
# 1286  F39574 2022-11-15  LETICIA RAMIREZ HERNANDEZ
#
# ...

# %%
filtro8a= df[(df["PRECIO_UNITARIO"] < 123) & (df["FECHA_DOC"] == "2022-01-26")]
filtro8a
#BUSCA LAS FILAS DONDE EL PRECIO UNITARIO SEA MAYOR A 123 EN UNA FECHA ESPECIFICA
# Out:
#    CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR         NOMBRE_CLIENTE  CANT  \
# 89  F37193 2022-01-26  LETICIA RAMIREZ HERNANDEZ  BESSER VACUUM AMERICA     1
#
#    CVE_ART                                 DESCR  PRECIO_UNITARIO  \
# 89  TP0001  TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 1 MT             98.0
#
#     COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  SUBTOTAL_PARTIDA  \
# 89           38.96                     38.96              98.0
#
#     COSTO_TOTAL_CALCULADO  MARGEN_UNITARIO_CALCULADO  MARGEN_TOTAL_CALCULADO
# 89                  38.96                      59.04                   59.04

# %%
filtro9a= df[(df["PRECIO_UNITARIO"] < 123) |  (df["FECHA_DOC"] == "05-01-2022")]
filtro9a
#BUSCA LAS FILAS DONDE EL PRECIO UNITARIO SEA MAYOR A 123 O EN UNA FECHA ESPECIFICA
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 7     F37046 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 89    F37193 2022-01-26  LETICIA RAMIREZ HERNANDEZ
# 93    F37214 2022-01-27  LETICIA RAMIREZ HERNANDEZ
# 192   F37422 2022-02-18  LETICIA RAMIREZ HERNANDEZ
# 307   F37612 2022-03-11  LETICIA RAMIREZ HERNANDEZ
# 344   F37692 2022-03-22  LETICIA RAMIREZ HERNANDEZ
# 346   F37695 2022-03-22  LETICIA RAMIREZ HERNANDEZ
# 372   F37731 2022-03-25  LETICIA RAMIREZ HERNANDEZ
# 422   F37824 2022-04-04  LETICIA RAMIREZ HERNANDEZ
# 489   F37951 2022-04-21  LETICIA RAMIREZ HERNANDEZ
# 549   F38083 2022-05-04  LETICIA RAMIREZ HERNANDEZ
# 676   F38364 2022-06-13             ALFREDO CANELA
# 926   F38836 2022-08-17  LETICIA RAMIREZ HERNANDEZ
# 1096  F39181 2022-09-29  LETICIA RAMIREZ HERNANDEZ
# 1240  F39470 2022-11-01  LETICIA RAMIREZ HERNANDEZ
# 1274  F39550 2022-11-11  LETICIA RAMIREZ HERNANDEZ
# 1286  F39574 2022-11-15  LETICIA RAMIREZ HERNANDEZ
#
# ...

# %%
filtro10a=df[~(df["FECHA_DOC"] == "05-01-2022")]
filtro10a
#BUSCA EN UNA FECHA ESPECIFICA
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3     F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                     NOMBRE_CLIENTE  CANT       CVE_ART  \
# 0               PÚBLICO EN GENERAL     1      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE     1      TUA00028
# 2        ANA BARBARA CRUZ PALACIOS     7        TP0007
# 3             OMAR RODRIGUEZ GOMEZ     1        TP0001
# 4               PÚBLICO EN GENERAL     2       BP00242
# ...

# %%
filtro1a.to_csv("Enrtegable1.csv")
filtro2a.to_csv("Enrtegable1.csv")
filtro3a.to_csv("Enrtegable1.csv")
filtro4a.to_csv("Enrtegable1.csv")
filtro5a.to_csv("Enrtegable1.csv")
filtro6a.to_csv("Enrtegable1.csv")
filtro7a.to_csv("Enrtegable1.csv")
filtro8a.to_csv("Enrtegable1.csv")
filtro9a.to_csv("Enrtegable1.csv")
filtro10a.to_csv("Enrtegable1.csv")
